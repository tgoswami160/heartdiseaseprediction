# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Reading

# %%
df=pd.read_csv("heart_disease_prediction.csv")
df
# Out:
#      Age  Sex  Chest_pain_type   BP  Cholesterol  FBS_over_120  EKG_results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
df.shape
# Out:
# (270, 14)

# %%
df.head()
# Out:
#    Age  Sex  Chest_pain_type   BP  Cholesterol  FBS_over_120  EKG_results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max_HR  Exercise_angina  ST_depression  Slope_of_ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number_of_vessels_fluro  Thallium Heart_Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest_pain_type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS_over_120             270 non-null    int64
#  6   EKG_results              270 non-null    int64
#  7   Max_HR                   270 non-null    int64
#  8   Exercise_angina          270 non-null    int64
#  9   ST_depression            270 non-null    float64
#  10  Slope_of_ST              270 non-null    int64
#  11  Number_of_vessels_fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart_Disease            270 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest_pain_type            0
# BP                         0
# Cholesterol                0
# FBS_over_120               0
# EKG_results                0
# Max_HR                     0
# Exercise_angina            0
# ST_depression              0
# Slope_of_ST                0
# Number_of_vessels_fluro    0
# Thallium                   0
# Heart_Disease              0
# dtype: int64

# %%
df.describe()
# Out:
#               Age         Sex  Chest_pain_type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS_over_120  EKG_results      Max_HR  Exercise_angina  ST_depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Chest_pain_type', 'BP', 'Cholesterol', 'FBS_over_120',
#        'EKG_results', 'Max_HR', 'Exercise_angina', 'ST_depression',
#        'Slope_of_ST', 'Number_of_vessels_fluro', 'Thallium', 'Heart_Disease'],
#       dtype='object')

# %%
df.count()
# Out:
# Age                        270
# Sex                        270
# Chest_pain_type            270
# BP                         270
# Cholesterol                270
# FBS_over_120               270
# EKG_results                270
# Max_HR                     270
# Exercise_angina            270
# ST_depression              270
# Slope_of_ST                270
# Number_of_vessels_fluro    270
# Thallium                   270
# Heart_Disease              270
# dtype: int64

# %% [markdown]
# # Visualizing Data

# %%
sns.barplot(x='Heart_Disease',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Heart_Disease', ylabel='Age'>

# %%
sns.barplot(x='Heart_Disease',y='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Heart_Disease', ylabel='Sex'>

# %%
sns.barplot(x='Heart_Disease',y='Chest_pain_type',data=df)
# Out:
# <AxesSubplot:xlabel='Heart_Disease', ylabel='Chest_pain_type'>

# %%
sns.barplot(x='Heart_Disease',y='BP',data=df)
# Out:
# <AxesSubplot:xlabel='Heart_Disease', ylabel='BP'>

# %%
sns.barplot(x='Heart_Disease',y='Cholesterol',data=df)
# Out:
# <AxesSubplot:xlabel='Heart_Disease', ylabel='Cholesterol'>

# %%
sns.barplot(x='Heart_Disease',y='Thallium',data=df)
# Out:
# <AxesSubplot:xlabel='Heart_Disease', ylabel='Thallium'>

# %%
plt.figure(figsize=(15,8))
sns.pairplot(df)
plt.show()

# %%
correlat = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlat, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':18}, cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Mining

# %%
df.replace(['Presence', 'Absence'],[1,0],inplace=True)
df
# Out:
#      Age  Sex  Chest_pain_type   BP  Cholesterol  FBS_over_120  EKG_results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %% [markdown]
# # Train Test

# %%
y=df['Heart_Disease']
X=df.drop(['Heart_Disease'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=19) 
X_train
# Out:
#      Age  Sex  Chest_pain_type   BP  Cholesterol  FBS_over_120  EKG_results  \
# 135   46    0                3  142          177             0            2
# 257   55    1                4  132          353             0            0
# 215   41    0                2  130          204             0            2
# 138   34    0                2  118          210             0            0
# 115   49    0                2  134          271             0            0
# ..   ...  ...              ...  ...          ...           ...          ...
# 159   66    0                4  178          228             1            0
# 19    40    1                1  140          199             0            0
# 245   60    1                4  130          253             0            0
# 110   55    0                4  180          327             0            1
# 93    54    1                4  110          206             0            2
#
# ...

# %%
X_test
# Out:
#      Age  Sex  Chest_pain_type   BP  Cholesterol  FBS_over_120  EKG_results  \
# 150   41    1                3  112          250             0            0
# 142   50    1                3  140          233             0            0
# 223   63    1                4  130          330             1            2
# 95    47    1                4  110          275             0            2
# 1     67    0                3  115          564             0            2
# 240   68    1                3  180          274             1            2
# 208   64    1                3  125          309             0            0
# 37    59    1                1  160          273             0            2
# 225   41    1                2  135          203             0            0
# 90    59    1                2  140          221             0            0
# 242   53    0                4  130          264             0            2
# ...

# %%
y_train
# Out:
# 135    0
# 257    1
# 215    0
# 138    0
# 115    0
#       ..
# 159    1
# 19     0
# 245    1
# 110    1
# 93     1
# Name: Heart_Disease, Length: 216, dtype: int64

# %%
y_test
# Out:
# 150    0
# 142    1
# 223    1
# 95     1
# 1      0
# 240    1
# 208    1
# 37     1
# 225    0
# 90     0
# 242    0
# 155    0
# 66     0
# 206    0
# 54     0
# 143    0
# 132    0
# 75     1
# 129    1
# 233    1
# 164    0
# 92     1
# 146    1
# 15     0
# 8      1
# 16     1
# 228    0
# 180    0
# 62     0
# 20     1
# 13     1
# 205    0
# 64     0
# 227    1
# 237    1
# 184    0
# 74     0
# 248    1
# 224    0
# 247    0
# 217    0
# 192    0
# 119    1
# 40     1
# 96     0
# 199    1
# 98     0
# 136    0
# 121    1
# 113    0
# 65     1
# 185    0
# 163    1
# 148    1
# Name: Heart_Disease, dtype: int64

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
clf.predict(X_test)
# Out:
# array([ 0.07976838,  0.60099543,  1.20447542,  0.75208928,  0.7635324 ,
#         0.68101029,  0.73603935,  0.10721484,  0.33816524,  0.07841083,
#         0.27805728, -0.20254124,  0.34772413,  0.15615822,  0.00134844,
#         0.32173866,  0.16396252,  1.2681188 ,  0.80389109,  0.73600597,
#         0.44608125,  1.07127974,  0.30936645,  0.10512817,  0.95034188,
#         1.17749988, -0.14017446,  0.42240988,  0.07456341,  1.09942711,
#         0.34428963,  0.27661684,  0.3452664 ,  0.81222626,  0.8362828 ,
#         0.49423231,  0.31681011,  0.26865228,  0.02222538,  0.03750286,
#         0.60746573,  0.35742262,  0.96365493,  0.44419487,  0.40650577,
#         0.79863354,  0.37842596,  0.09643558,  0.96216813, -0.04618436,
#         0.96880117,  0.39277073,  1.16676501,  0.7553791 ])

# %%
y_test
# Out:
# 150    0
# 142    1
# 223    1
# 95     1
# 1      0
# 240    1
# 208    1
# 37     1
# 225    0
# 90     0
# 242    0
# 155    0
# 66     0
# 206    0
# 54     0
# 143    0
# 132    0
# 75     1
# 129    1
# 233    1
# 164    0
# 92     1
# 146    1
# 15     0
# 8      1
# 16     1
# 228    0
# 180    0
# 62     0
# 20     1
# 13     1
# 205    0
# 64     0
# 227    1
# 237    1
# 184    0
# 74     0
# 248    1
# 224    0
# 247    0
# 217    0
# 192    0
# 119    1
# 40     1
# 96     0
# 199    1
# 98     0
# 136    0
# 121    1
# 113    0
# 65     1
# 185    0
# 163    1
# 148    1
# Name: Heart_Disease, dtype: int64

# %%
clf.score(X_test, y_test)
# Out:
# 0.5206736869281634

# %% [markdown]
# # Logical Regression

# %%
from sklearn import linear_model
reg=linear_model.LogisticRegression()
reg.fit(df.drop('Heart_Disease',axis='columns'),df.Heart_Disease)
# Out:
# C:\Users\Tanu gosawami\anaconda2\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_test
clf.predict(X_test)
# Out:
# array([ 0.07976838,  0.60099543,  1.20447542,  0.75208928,  0.7635324 ,
#         0.68101029,  0.73603935,  0.10721484,  0.33816524,  0.07841083,
#         0.27805728, -0.20254124,  0.34772413,  0.15615822,  0.00134844,
#         0.32173866,  0.16396252,  1.2681188 ,  0.80389109,  0.73600597,
#         0.44608125,  1.07127974,  0.30936645,  0.10512817,  0.95034188,
#         1.17749988, -0.14017446,  0.42240988,  0.07456341,  1.09942711,
#         0.34428963,  0.27661684,  0.3452664 ,  0.81222626,  0.8362828 ,
#         0.49423231,  0.31681011,  0.26865228,  0.02222538,  0.03750286,
#         0.60746573,  0.35742262,  0.96365493,  0.44419487,  0.40650577,
#         0.79863354,  0.37842596,  0.09643558,  0.96216813, -0.04618436,
#         0.96880117,  0.39277073,  1.16676501,  0.7553791 ])

# %%
print(clf.score(X_test, y_test))
# Out:
# 0.5206736869281634
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87        33
#            1       0.76      0.90      0.83        21
#
#     accuracy                           0.85        54
#    macro avg       0.85      0.86      0.85        54
# weighted avg       0.86      0.85      0.85        54

# %%
y=df['Heart_Disease']
x=df.iloc[:,0:13]

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=19)
print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
#      Age  Sex  Chest_pain_type   BP  Cholesterol  FBS_over_120  EKG_results  \
# 135   46    0                3  142          177             0            2
# 257   55    1                4  132          353             0            0
# 215   41    0                2  130          204             0            2
# 138   34    0                2  118          210             0            0
# 115   49    0                2  134          271             0            0
# ..   ...  ...              ...  ...          ...           ...          ...
# 159   66    0                4  178          228             1            0
# 19    40    1                1  140          199             0            0
# 245   60    1                4  130          253             0            0
# 110   55    0                4  180          327             0            1
# 93    54    1                4  110          206             0            2
#
# ...

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import accuracy_score
y_pred=svc.predict(x_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.7407407407407407

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.69      0.79        39
#            1       0.52      0.87      0.65        15
#
#     accuracy                           0.74        54
#    macro avg       0.73      0.78      0.72        54
# weighted avg       0.82      0.74      0.75        54

# %%
from sklearn.metrics import confusion_matrix
z=confusion_matrix(y_pred,y_test)
import seaborn as sns
sns.heatmap(z,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
from sklearn.metrics import accuracy_score
print('Testing Acc=',accuracy_score(y_test,y_pred))
print(classification_report(y_pred,y_test))
# Out:
# Testing Acc= 0.8518518518518519
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87        33
#            1       0.76      0.90      0.83        21
#
#     accuracy                           0.85        54
#    macro avg       0.85      0.86      0.85        54
# weighted avg       0.86      0.85      0.85        54

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier

# %%
from sklearn.naive_bayes import GaussianNB
cl=GaussianNB()
cl.fit(x_train,y_train)
y_pred=cl.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8703703703703703

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88        30
#            1       0.84      0.88      0.86        24
#
#     accuracy                           0.87        54
#    macro avg       0.87      0.87      0.87        54
# weighted avg       0.87      0.87      0.87        54

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
cl=DecisionTreeClassifier()
cl.fit(x_train,y_train)
y_pred=cl.predict(x_test)
from sklearn.metrics import accuracy_score
(accuracy_score(y_test,y_pred))
# Out:
# 0.7222222222222222

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.82      0.71        22
#            1       0.84      0.66      0.74        32
#
#     accuracy                           0.72        54
#    macro avg       0.73      0.74      0.72        54
# weighted avg       0.75      0.72      0.72        54

# %%
a=['SVC','Naive Bayes','Decision Tree','Random forest','Logistic Regression']
b=[74.04,87.00,87.03,72.20,52.60]
plt.figure(figsize=(16,9))
plt.bar(a,b,width=0.4)
plt.xticks(fontsize=15)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
